# %%
#@title 1️⃣ نصب پیش نیازها { display-mode: "form" }

import base64
exec(base64.b64decode("cHJpbnQoIk5vdGVib29rIHJld3JpdGUgYnkgYWlnb2xkZW4iKQ==").decode())

import os

if not os.path.exists('/content/seed-vc'):
    # !git clone https://github.com/Plachtaa/seed-vc.git /content/seed-vc

# %cd /content/seed-vc

print("📦 در حال نصب کتابخونه‌های سبک...")
# !pip install -q librosa huggingface-hub munch einops pydub soundfile sounddevice pyyaml python-dotenv jiwer

print("📦 در حال نصب gradio...")
# !pip install -q gradio==5.23.0

print("📦 در حال نصب transformers...")
# !pip install -q transformers==4.46.3

print("📦 در حال نصب descript-audio-codec (ممکنه چند دقیقه طول بکشه)...")
# !pip install -q descript-audio-codec==1.0.0

print("📦 در حال نصب resemblyzer...")
# !pip install -q resemblyzer

print("📦 در حال نصب modelscope و funasr (سنگین‌ترین بخش، صبور باش)...")
# !pip install -q modelscope==1.18.1 funasr==1.1.5

print("✅ نصب با موفقیت انجام شد.")

# %%
#@title 2️⃣ اجرای برنامه (ساخت لینک عمومی) { display-mode: "form" }
#@markdown بعد از اجرای این سلول چند دقیقه صبر کن تا مدل‌ها دانلود بشن، سپس یک لینک به شکل `https://xxxxx.gradio.live` نمایش داده میشه. روی اون لینک بزن تا رابط کاربری باز بشه (دقیقاً شبیه هاگینگ‌فیس، با تمام اسلایدرها).

# %cd /content/seed-vc

# !sed -i 's/\.launch()/\.launch(share=True)/' app_vc_v2.py

# !python app_vc_v2.py

# %% [markdown]
# ### ℹ️ توضیح کوتاه اسلایدرها
#
# | اسلایدر | کاربرد |
# |---|---|
# | Diffusion Steps | تعداد قدم‌های ساخت صدا؛ بیشتر = کیفیت بهتر، کندتر |
# | Length Adjust | تنظیم سرعت گفتار |
# | Intelligibility CFG Rate | وضوح تلفظ کلمات |
# | Similarity CFG Rate | شباهت خروجی به صدای رفرنس |
# | Top-p | تنوع در انتخاب مدل |
# | Temperature | خلاقیت در انتخاب |
# | Repetition Penalty | جلوگیری از تکرار الگوی صوتی |
